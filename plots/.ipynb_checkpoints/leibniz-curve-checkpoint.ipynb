# %%
from matplotlib import pyplot as plt
from matplotlib import rc
from matplotlib import patheffects
from cycler import cycler
import numpy as np

# %%
rc('figure', dpi=150)
rc('axes', prop_cycle=cycler(color=plt.get_cmap('PuBu')(np.linspace(0.9, 0, 15))))
plt.xkcd()
plt.rcParams['path.effects'] = [patheffects.withStroke(linewidth=0)]

# %%
t = np.linspace(0, 10, 1000)
x = (2/3) * np.sqrt(2*t**3)
y = -t

# %%
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim([0, 30])
plt.ylim([-10, 0])
plt.tight_layout()
plt.title('Leibniz isochronous curve')
plt.savefig('test.png', transparent=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import patheffects

plt.style.use(['dark_background'])
plt.xkcd()
plt.rcParams['path.effects'] = [patheffects.withStroke(linewidth=0)]

plt.rcParams['figure.facecolor'] = 'black'

x = np.linspace(-5, 5)

plt.figure()
plt.plot(x, x**2)
plt.text(0, 10, "Text", color='r', fontsize=20)
plt.xlabel("$x$"   )
plt.ylabel("$f(x)$")
plt.show();
